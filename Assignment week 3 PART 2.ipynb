# %%
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
url
# Out:
# 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
results = requests.get(url).text

soup = BeautifulSoup(results, 'lxml')

# %%
table = soup.find('tbody')

# %%
data = []
cells= table.findAll('td')
for cell in cells:
    row = []
    if cell.find('a') is not None: #Cells with a borough that is NOT ASSIGNED do not have <a> elements.
        if len(cell.findAll('a'))==1:
            row.append(cell.b.text)
            row.append(cell.findAll('a')[0].text)
            row.append(cell.findAll('a')[0].text)
        elif len(cell.findAll('a'))==2:
            row.append(cell.b.text)
            row.append(cell.findAll('a')[0].text)
            row.append(cell.findAll('a')[1].text)
        elif len(cell.findAll('a'))>2:
            nbhs =''
            for i in range(1,len(cell.findAll('a')) ):
                nbhs = nbhs+cell.findAll('a')[i].text+', '
            nbhs = nbhs[:-2]
            row.append(cell.b.text)
            row.append(cell.findAll('a')[0].text)
            row.append(nbhs)
        data.append(row)
data
# Out:
# [['M3A', 'North York', 'Parkwoods'],
#  ['M4A', 'North York', 'Victoria Village'],
#  ['M5A', 'Downtown Toronto', 'Regent Park, Harbourfront'],
#  ['M6A', 'North York', 'Lawrence Manor, Lawrence Heights'],
#  ['M7A', "Queen's Park", 'Ontario Provincial Government'],
#  ['M9A', 'Etobicoke', 'Islington Avenue'],
#  ['M1B', 'Scarborough', 'Malvern, Rouge'],
#  ['M3B', 'North York', 'Don Mills'],
#  ['M4B', 'East York', 'Parkview Hill, Woodbine Gardens'],
#  ['M5B', 'Downtown Toronto', 'Garden District, Ryerson'],
#  ['M6B', 'North York', 'North York'],
#  ['M9B',
#   'Etobicoke',
#   'West Deane Park, Princess Gardens, Martin Grove, Islington'],
#  ['M1C', 'Scarborough', 'Rouge Hill, Port Union, Highland Creek'],
#  ['M3C', 'North York', 'Don Mills, Flemingdon Park'],
#  ['M4C', 'East York', 'Woodbine Heights'],
#  ['M5C', 'Downtown Toronto', 'St. James Town'],
#  ['M6C', 'York', 'Humewood-Cedarvale'],
#  ['M9C', 'Etobicoke', 'Markland Wood'],
# ...

# %%
df = pd.DataFrame(data, columns = ['PostalCode', 'Borough','Neighborhood'])
df.head(15)
# Out:
#    PostalCode           Borough  \
# 0         M3A        North York
# 1         M4A        North York
# 2         M5A  Downtown Toronto
# 3         M6A        North York
# 4         M7A      Queen's Park
# 5         M9A         Etobicoke
# 6         M1B       Scarborough
# 7         M3B        North York
# 8         M4B         East York
# 9         M5B  Downtown Toronto
# 10        M6B        North York
# 11        M9B         Etobicoke
# 12        M1C       Scarborough
# 13        M3C        North York
# 14        M4C         East York
#
#                                          Neighborhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                           Regent Park, Harbourfront
# 3                    Lawrence Manor, Lawrence Heights
# 4                       Ontario Provincial Government
# 5                                    Islington Avenue
# 6                                      Malvern, Rouge
# ...

# %%
coord = pd.read_csv('Geospatial_Coordinates.csv')
coord.head(15)
# Out:
#    Postal Code   Latitude  Longitude
# 0          M1B  43.806686 -79.194353
# 1          M1C  43.784535 -79.160497
# 2          M1E  43.763573 -79.188711
# 3          M1G  43.770992 -79.216917
# 4          M1H  43.773136 -79.239476
# 5          M1J  43.744734 -79.239476
# 6          M1K  43.727929 -79.262029
# 7          M1L  43.711112 -79.284577
# 8          M1M  43.716316 -79.239476
# 9          M1N  43.692657 -79.264848
# 10         M1P  43.757410 -79.273304
# 11         M1R  43.750072 -79.295849
# 12         M1S  43.794200 -79.262029
# 13         M1T  43.781638 -79.304302
# 14         M1V  43.815252 -79.284577

# %%
coord.columns = ['PostalCode','Latitude','Longitude']
coord.head(15)
# Out:
#    PostalCode   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848
# 10        M1P  43.757410 -79.273304
# 11        M1R  43.750072 -79.295849
# 12        M1S  43.794200 -79.262029
# 13        M1T  43.781638 -79.304302
# 14        M1V  43.815252 -79.284577

# %%
final_df = pd.merge(df, coord, how='inner', on=['PostalCode'])
final_df
# Out:
#     PostalCode              Borough  \
# 0          M3A           North York
# 1          M4A           North York
# 2          M5A     Downtown Toronto
# 3          M6A           North York
# 4          M7A         Queen's Park
# 5          M9A            Etobicoke
# 6          M1B          Scarborough
# 7          M3B           North York
# 8          M4B            East York
# 9          M5B     Downtown Toronto
# 10         M6B           North York
# 11         M9B            Etobicoke
# 12         M1C          Scarborough
# 13         M3C           North York
# 14         M4C            East York
# 15         M5C     Downtown Toronto
# 16         M6C                 York
# 17         M9C            Etobicoke
# 18         M1E          Scarborough
# 19         M4E          The Beaches
# 20         M5E     Downtown Toronto
# 21         M6E                 York
# 22         M1G          Scarborough
# 23         M4G            East York
# 24         M5G     Downtown Toronto
# ...
